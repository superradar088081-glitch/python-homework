# %% [markdown]
# # แบบทดสอบการจัดการกับ List

# %%
lt = [1, 2, 3, 4, 5]

# %% [markdown]
# ## 1. เพิ่มข้อมูลเข้าไปใน list ทีละตัว
#
# 100, 200, 300, 400

# %%
lt.append (100)

# %%
lt.append (200)

# %%
lt.append (300)

# %%
lt.append (400)

# %%
print(lt)
# Out:
# [1, 2, 3, 4, 5, 100, 200, 300, 400]

# %% [markdown]
# ## 2. นำ List เพิ่มเข้าใน lt

# %%
sub = [6, 7, 8, 9, 10]

# %%
lt.append (sub)

# %%
print (lt)
# Out:
# [1, 2, 3, 4, 5, 100, 200, 300, 400, [6, 7, 8, 9, 10]]

# %% [markdown]
# ## 3. เข้าถึงเข้ามูลตัวสุดท้ายภายใน list

# %%
lt [-1]
# Out:
# [6, 7, 8, 9, 10]

# %% [markdown]
# ## 4. นำข้อมูลตัวสุดท้ายออกจาก list

# %%
lt.pop()
lt
# Out:
# [1, 2, 3, 4, 5, 100, 200, 300, 400]

# %% [markdown]
# ## 5. นำข้อมูลตัวที่ 5 ออกจาก list

# %%
del lt[5]

# %%
lt
# Out:
# [1, 2, 3, 4, 5, 200, 300, 400]

# %% [markdown]
# ## 6. เพิ่มคำว่า "Python" เข้าไปใน list ตำแหน่งที่ 3

# %%
lt.insert (2,"python")

# %%
lt
# Out:
# [1, 2, 'python', 3, 4, 5, 200, 300, 400]

# %% [markdown]
# ## 7. ลบข้อมูลในตำแหน่งที่ 6 ออกจาก list

# %%
del lt [5]

# %%
lt
# Out:
# [1, 2, 'python', 3, 4, 300, 400]

# %% [markdown]
# ## 8. แสดงจำนวนสมาชิกภายใน list

# %%
 len (lt)
# Out:
# 7

# %% [markdown]
# ## 9. reverse list

# %%
"python"[::-1]
# Out:
# 'nohtyp'

# %%
lt.reverse()
lt
# Out:
# [400, 300, 4, 3, 'python', 2, 1]

# %% [markdown]
# ## 10. เคลียร์ list ให้เป็น list ว่าง

# %%
lt.clear()

# %%
lt
# Out:
# []
